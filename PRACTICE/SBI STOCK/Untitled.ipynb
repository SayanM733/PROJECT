# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

df = pd.read_csv(r'E:\ML\PROJECT\PRACTICE\SBI STOCK\SBI_BANK.csv')
df.dropna(inplace=True)
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     03-01-2000   22.267092   22.988886   22.101974   22.988886   16.110510
# 1     04-01-2000   22.988886   24.720245   22.535995   24.446625   17.132088
# 2     05-01-2000   23.493668   24.974997   23.116261   23.441774   16.427893
# 3     06-01-2000   23.776726   25.286358   23.776726   24.625893   17.257719
# 4     07-01-2000   24.673071   26.409147   24.059780   25.786425   18.071014
# ...          ...         ...         ...         ...         ...         ...
# 5868  19-06-2023  571.250000  572.750000  565.900024  568.849976  568.849976
# 5869  20-06-2023  568.849976  569.450012  562.549988  567.400024  567.400024
# 5870  21-06-2023  567.400024  569.500000  565.650024  566.349976  566.349976
# 5871  22-06-2023  566.349976  569.000000  561.049988  562.950012  562.950012
# 5872  23-06-2023  562.000000  562.099976  553.799988  554.599976  554.599976
#
#           Volume         VWAP
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
# Define the features and target variable
features = ['Open', 'Volume', 'VWAP']  # Remove inner list
X = df[features]
y = df['Close']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize the RandomForestRegressor with corrected parameters
sbi = KNeighborsRegressor(n_neighbors=1)

# Train the model
sbi.fit(X,y)

# Make predictions
y_pred = sbi.predict([[577.750000,11777454,573.25]])
print(y_pred)
print("Predicted Close Price:", y_pred[0])
# Out:
# [216.615005]
# Predicted Close Price: 216.615005
# C:\Users\Sayan\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# Define the features and target variable
features = ['Open', 'Volume', 'VWAP']  # Remove inner list
X = df[features]
y = df['Close']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize the RandomForestRegressor with corrected parameters
sbi = RandomForestRegressor(n_estimators=30, random_state=42)

sbi.fit(X,y)

# Make predictions
y_pred = sbi.predict([[577.750000,11777454,573.25]])
print(y_pred)
print("Predicted Close Price:", y_pred[0])
# Out:
# [572.1900004]
# Predicted Close Price: 572.1900004
# C:\Users\Sayan\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
